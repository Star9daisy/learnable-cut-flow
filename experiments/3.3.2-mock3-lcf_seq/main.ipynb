# %%
# System
import os
import sys

os.environ["KERAS_BACKEND"] = "jax"
sys.path.append("../..")

# %%
# Setup
from importlib import import_module
from typing import cast

import numpy as np
from keras import ops
from keras.models import Model

from src.utils import (
    load_model,
    show_learned_cut,
    show_learned_cuts,
    show_learned_importance,
)

# %%
# Parameters
# Dataset
dataset_name = "mock3"  # *
n_samples = 200000
seed = 42

# Model
model_builder_name = "LearnableCutFlowSequential"  # *
centers = [-2, -5, 5]  # *
n_epochs = 200
batch_size = 512

# Plotting
bins = np.linspace(-10, 10, 101)
feature_names = ["x1", "x7", "x8"]  # *
feature_names_latex = [r"$x_1$", r"$x_7$", r"$x_8$"]  # *

# %%
# Dataset
module = import_module(f"src.datasets.{dataset_name}")
load_data = getattr(module, "load_data")
(x_train, y_train), (x_test, y_test) = load_data(n_samples, seed)

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")
# Out:
# x_train.shape=(100000, 3)
# y_train.shape=(100000, 1)
# x_test.shape=(100000, 3)
# y_test.shape=(100000, 1)

# %%
# Model
ModelBuilder = getattr(import_module("src.models"), model_builder_name)
model = ModelBuilder(x_train.shape, centers, name="lcf_seq")

model.normalization.adapt(x_train)
model.compile(optimizer="adam", loss="crossentropy")
model.fit(x_train, y_train, epochs=n_epochs, batch_size=batch_size)

model.save("checkpoint.keras")
# Out:
# Epoch 1/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1363
# Epoch 2/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1258
# Epoch 3/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.1179
# Epoch 4/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1123
# Epoch 5/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1077
# Epoch 6/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1030
# Epoch 7/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0981
# Epoch 8/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0986
# Epoch 9/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1353
# Epoch 10/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1339
# Epoch 11/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1329
# Epoch 12/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 13/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1314
# Epoch 14/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1303
# Epoch 15/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1307
# Epoch 16/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 17/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1311
# Epoch 18/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1302
# Epoch 19/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1311
# Epoch 20/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 21/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.1316
# Epoch 22/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1313
# Epoch 23/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1312
# Epoch 24/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.1315
# Epoch 25/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1319
# Epoch 26/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.1313
# Epoch 27/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.1322
# Epoch 28/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 29/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 30/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1322
# Epoch 31/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1329
# Epoch 32/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 33/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1332
# Epoch 34/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 35/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.1334
# Epoch 36/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1327
# Epoch 37/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1312
# Epoch 38/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1332
# Epoch 39/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333
# Epoch 40/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1339
# Epoch 41/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1326
# Epoch 42/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1313
# Epoch 43/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.1343
# Epoch 44/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 45/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.1328
# Epoch 46/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.1327
# Epoch 47/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1327
# Epoch 48/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 49/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 50/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 51/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333
# Epoch 52/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1327
# Epoch 53/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1322
# Epoch 54/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 55/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 56/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 57/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 58/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1327
# Epoch 59/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 60/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 61/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 62/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 63/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1326
# Epoch 64/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 65/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.1324
# Epoch 66/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333
# Epoch 67/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1330
# Epoch 68/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 69/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.1325
# Epoch 70/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 71/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1331
# Epoch 72/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1329
# Epoch 73/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1324
# Epoch 74/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1337
# Epoch 75/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333
# Epoch 76/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.1323
# Epoch 77/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1329
# Epoch 78/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1324
# Epoch 79/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 80/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.1334
# Epoch 81/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.1325
# Epoch 82/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1332
# Epoch 83/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 84/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 85/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1330
# Epoch 86/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 87/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1322
# Epoch 88/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1327
# Epoch 89/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 90/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.1335
# Epoch 91/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 92/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 93/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1322
# Epoch 94/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 95/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 96/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 97/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 98/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1336
# Epoch 99/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1330
# Epoch 100/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1319
# Epoch 101/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1336
# Epoch 102/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 103/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1325
# Epoch 104/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 105/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1319
# Epoch 106/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1329
# Epoch 107/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 108/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.1322
# Epoch 109/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1315
# Epoch 110/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1339
# Epoch 111/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 112/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333
# Epoch 113/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1313
# Epoch 114/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1324
# Epoch 115/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1312
# Epoch 116/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1318
# Epoch 117/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 118/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1327
# Epoch 119/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 120/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 121/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1322
# Epoch 122/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.1329
# Epoch 123/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1322
# Epoch 124/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1319
# Epoch 125/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 126/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 127/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 128/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 129/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 130/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 131/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 132/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 133/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1330
# Epoch 134/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1315
# Epoch 135/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 136/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 137/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1323
# Epoch 138/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1347
# Epoch 139/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 140/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1307
# Epoch 141/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310
# Epoch 142/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 143/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1332
# Epoch 144/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 145/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 146/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1315
# Epoch 147/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1330
# Epoch 148/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 149/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1315
# Epoch 150/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1324
# Epoch 151/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1331
# Epoch 152/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1328
# Epoch 153/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1316
# Epoch 154/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1318
# Epoch 155/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1324
# Epoch 156/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 157/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.1326
# Epoch 158/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 159/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 160/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1325
# Epoch 161/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1322
# Epoch 162/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1303
# Epoch 163/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1320
# Epoch 164/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1327
# Epoch 165/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310
# Epoch 166/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1324
# Epoch 167/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 168/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1309
# Epoch 169/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1314
# Epoch 170/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1320
# Epoch 171/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1309
# Epoch 172/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310
# Epoch 173/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1319
# Epoch 174/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1309
# Epoch 175/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1320
# Epoch 176/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1308
# Epoch 177/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1304
# Epoch 178/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1301
# Epoch 179/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1293
# Epoch 180/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310
# Epoch 181/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1302
# Epoch 182/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1301
# Epoch 183/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1303
# Epoch 184/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1304
# Epoch 185/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1298
# Epoch 186/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1298
# Epoch 187/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1305
# Epoch 188/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310
# Epoch 189/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1300
# Epoch 190/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1291
# Epoch 191/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1298
# Epoch 192/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1291
# Epoch 193/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1293
# Epoch 194/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1289
# Epoch 195/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1299
# Epoch 196/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1296
# Epoch 197/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1289
# Epoch 198/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1288
# Epoch 199/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1288
# Epoch 200/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1284

# %%
# Checkpoint
checkpoint = cast(Model, load_model("checkpoint.keras"))

# %%
# Analysis: metrics
y_pred = checkpoint.predict(x_test, batch_size=batch_size)
y_true = y_test

tp = ops.sum((y_true == 1) & (y_pred == 1))
fp = ops.sum((y_true == 0) & (y_pred == 1))
tn = ops.sum((y_true == 0) & (y_pred == 0))
fn = ops.sum((y_true == 1) & (y_pred == 0))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# True positives.......41929
# False positives.......8071
# Accuracy............0.8400
# Precision...........0.8386
# Significance......466.7140

# %%
# Analysis: check metrics via learned cuts
mask = ops.ones_like(x_test[:, 0], dtype="bool")
n_features = x_test.shape[1]
selection = (
    checkpoint.learned_importance > 1 / n_features * checkpoint.importance_min_percent
)
for i, cut_report in enumerate(checkpoint.learned_cuts_report):
    if not selection[i]:
        continue

    x_i = x_test[:, i]
    boundaries = cut_report["boundaries"]
    index = cut_report["index"]

    if cut_report["case"] == "left":
        mask_i = x_i < boundaries[index]
    elif cut_report["case"] == "right":
        mask_i = x_i > boundaries[index]
    elif cut_report["case"] == "middle":
        mask_i = ops.logical_and(boundaries[0] < x_i, x_i < boundaries[1])
    else:
        mask_i = ops.logical_or(x_i < boundaries[0], boundaries[1] < x_i)
    mask = ops.logical_and(mask, mask_i)

y_pred_cut = ops.cast(mask, dtype="float32")
y_pred_cut = ops.reshape(y_pred_cut, y_test.shape)
tp = ops.sum((y_pred_cut == 1) & (y_test == 1))
fp = ops.sum((y_pred_cut == 1) & (y_test == 0))
tn = ops.sum((y_pred_cut == 0) & (y_test == 0))
fn = ops.sum((y_pred_cut == 0) & (y_test == 1))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# True positives.......41929
# False positives.......8071
# Accuracy............0.8400
# Precision...........0.8386
# Significance......466.7140

# %%
# Analysis: learned cuts
for learned_cut in checkpoint.learned_cuts:
    print(learned_cut)
# Out:
# x1 < 0.0167
# x2 > -152.9070
# x3 < 1924.0260 or x3 > -1317.4424

# %%
# Figure: learned cuts
show_learned_cuts(checkpoint, x_test, y_test, bins, feature_names_latex)

for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/learned_cut-{feature_names[i]}.pdf",
    )

# %%
# Figure: learned importance
show_learned_importance(checkpoint, feature_names_latex)

show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file="figures/learned_importance.pdf",
)
