# %%
# System
import os
import sys

os.environ["KERAS_BACKEND"] = "jax"
sys.path.append("../..")

# %%
# Setup
from importlib import import_module
from typing import cast

import numpy as np
from keras import ops
from keras.models import Model

from src.utils import (
    load_model,
    show_learned_cut,
    show_learned_cuts,
    show_learned_importance,
)

# %%
# Parameters
# Dataset
dataset_name = "mock6"  # *
n_samples = 200000
seed = 42

# Model
model_builder_name = "LearnableCutFlowSequential"  # *
centers = [-2, 2, 0, 0, -1, -5, -1.8]  # *
n_epochs = 200
batch_size = 512

# Plotting
bins = np.linspace(-10, 10, 101)
feature_names = ["x1", "x2", "x3", "x4", "x5", "x7", "x9"]  # *
feature_names_latex = [
    r"$x_1$",
    r"$x_2$",
    r"$x_3$",
    r"$x_4$",
    r"$x_5$",
    r"$x_7$",
    r"$x_9$",
]  # *

# %%
# Dataset
module = import_module(f"src.datasets.{dataset_name}")
load_data = getattr(module, "load_data")
(x_train, y_train), (x_test, y_test), order = load_data(n_samples, seed)

centers = [centers[i] for i in order]
feature_names = [feature_names[i] for i in order]
feature_names_latex = [feature_names_latex[i] for i in order]

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")
# Out:
# x_train.shape=(100000, 7)
# y_train.shape=(100000, 1)
# x_test.shape=(100000, 7)
# y_test.shape=(100000, 1)

# %%
# Model
ModelBuilder = getattr(import_module("src.models"), model_builder_name)
model = ModelBuilder(
    x_train.shape, centers, feature_names=feature_names, name="lcf_seq"
)
model.normalization.adapt(x_train)

model.compile(optimizer="adam", loss="crossentropy")
model.fit(x_train, y_train, epochs=n_epochs, batch_size=batch_size)

model.save("checkpoint.keras")
# Out:
# Epoch 1/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.1068
# Epoch 2/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0987
# Epoch 3/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0908
# Epoch 4/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0813
# Epoch 5/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0680
# Epoch 6/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0583
# Epoch 7/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0696
# Epoch 8/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1192
# Epoch 9/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1066
# Epoch 10/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1021
# Epoch 11/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1197
# Epoch 12/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1126
# Epoch 13/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1190
# Epoch 14/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1202
# Epoch 15/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1154
# Epoch 16/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1111
# Epoch 17/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1064
# Epoch 18/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1045
# Epoch 19/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1028
# Epoch 20/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1015
# Epoch 21/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1007
# Epoch 22/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1003
# Epoch 23/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0998
# Epoch 24/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0994
# Epoch 25/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0976
# Epoch 26/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0960
# Epoch 27/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0950
# Epoch 28/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0936
# Epoch 29/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0937
# Epoch 30/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0912
# Epoch 31/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0884
# Epoch 32/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0866
# Epoch 33/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0852
# Epoch 34/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0835
# Epoch 35/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0827
# Epoch 36/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0824
# Epoch 37/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0812
# Epoch 38/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0806
# Epoch 39/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0800
# Epoch 40/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0798
# Epoch 41/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0778
# Epoch 42/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0770
# Epoch 43/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0755
# Epoch 44/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0744
# Epoch 45/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0732
# Epoch 46/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0726
# Epoch 47/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0717
# Epoch 48/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0705
# Epoch 49/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0701
# Epoch 50/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0698
# Epoch 51/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0681
# Epoch 52/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0686
# Epoch 53/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0677
# Epoch 54/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0673
# Epoch 55/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0662
# Epoch 56/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0662
# Epoch 57/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0653
# Epoch 58/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0655
# Epoch 59/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0645
# Epoch 60/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0641
# Epoch 61/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0634
# Epoch 62/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0637
# Epoch 63/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0627
# Epoch 64/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0617
# Epoch 65/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0624
# Epoch 66/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0619
# Epoch 67/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0619
# Epoch 68/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0611
# Epoch 69/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0617
# Epoch 70/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0617
# Epoch 71/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608
# Epoch 72/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0606
# Epoch 73/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0609
# Epoch 74/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0604
# Epoch 75/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0606
# Epoch 76/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0605
# Epoch 77/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0593
# Epoch 78/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0592
# Epoch 79/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0592
# Epoch 80/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0594
# Epoch 81/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0593
# Epoch 82/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0581
# Epoch 83/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0588
# Epoch 84/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0581
# Epoch 85/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0587
# Epoch 86/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0583
# Epoch 87/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0584
# Epoch 88/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580
# Epoch 89/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0575
# Epoch 90/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580
# Epoch 91/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0573
# Epoch 92/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580
# Epoch 93/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0586
# Epoch 94/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0573
# Epoch 95/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0576
# Epoch 96/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0579
# Epoch 97/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0570
# Epoch 98/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0566
# Epoch 99/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0571
# Epoch 100/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0567
# Epoch 101/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0570
# Epoch 102/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0568
# Epoch 103/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561
# Epoch 104/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0571
# Epoch 105/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0572
# Epoch 106/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0569
# Epoch 107/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561
# Epoch 108/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561
# Epoch 109/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0563
# Epoch 110/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0565
# Epoch 111/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559
# Epoch 112/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0571
# Epoch 113/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0562
# Epoch 114/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0564
# Epoch 115/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0564
# Epoch 116/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 117/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559
# Epoch 118/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 119/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563
# Epoch 120/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0562
# Epoch 121/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0565
# Epoch 122/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0567
# Epoch 123/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 124/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556
# Epoch 125/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0565
# Epoch 126/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0555
# Epoch 127/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0565
# Epoch 128/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0558
# Epoch 129/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0567
# Epoch 130/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554
# Epoch 131/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559
# Epoch 132/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561
# Epoch 133/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0555
# Epoch 134/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 135/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0559
# Epoch 136/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0559
# Epoch 137/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0558
# Epoch 138/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0558
# Epoch 139/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 140/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561
# Epoch 141/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 142/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 143/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 144/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 145/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 146/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0559
# Epoch 147/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561
# Epoch 148/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 149/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0564
# Epoch 150/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 151/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 152/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561
# Epoch 153/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0559
# Epoch 154/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 155/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0563
# Epoch 156/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0551
# Epoch 157/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 158/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0553
# Epoch 159/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553
# Epoch 160/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555
# Epoch 161/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0549
# Epoch 162/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0558
# Epoch 163/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 164/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556
# Epoch 165/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0557
# Epoch 166/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 167/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0558
# Epoch 168/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552
# Epoch 169/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552
# Epoch 170/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552
# Epoch 171/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563
# Epoch 172/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561
# Epoch 173/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556
# Epoch 174/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 175/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553
# Epoch 176/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560
# Epoch 177/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0550
# Epoch 178/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0554
# Epoch 179/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0555
# Epoch 180/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557
# Epoch 181/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0558
# Epoch 182/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563
# Epoch 183/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561
# Epoch 184/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0565
# Epoch 185/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0554
# Epoch 186/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0557
# Epoch 187/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555
# Epoch 188/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553
# Epoch 189/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0551
# Epoch 190/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0553
# Epoch 191/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 192/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 193/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0555
# Epoch 194/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0552
# Epoch 195/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554
# Epoch 196/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554
# Epoch 197/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0556
# Epoch 198/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0543
# Epoch 199/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556
# Epoch 200/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0560

# %%
# Checkpoint
checkpoint = cast(Model, load_model("checkpoint.keras"))

# %%
# Analysis: metrics
y_pred = checkpoint.predict(x_test, batch_size=batch_size)
y_true = y_test

tp = ops.sum((y_true == 1) & (y_pred == 1))
fp = ops.sum((y_true == 0) & (y_pred == 1))
tn = ops.sum((y_true == 0) & (y_pred == 0))
fn = ops.sum((y_true == 1) & (y_pred == 0))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step
# True positives.......40148
# False positives.......1568
# Accuracy............0.8845
# Precision...........0.9624
# Significance.....1013.8902

# %%
# Analysis: check metrics via learned cuts
mask = ops.ones_like(x_test[:, 0], dtype="bool")
n_features = x_test.shape[1]
selection = (
    checkpoint.learned_importance > 1 / n_features * checkpoint.importance_min_percent
)
for i, cut_report in enumerate(checkpoint.learned_cuts_report):
    if not selection[i]:
        continue

    x_i = x_test[:, i]
    boundaries = cut_report["boundaries"]
    index = cut_report["index"]

    if cut_report["case"] == "left":
        mask_i = x_i < boundaries[index]
    elif cut_report["case"] == "right":
        mask_i = x_i > boundaries[index]
    elif cut_report["case"] == "middle":
        mask_i = ops.logical_and(boundaries[0] < x_i, x_i < boundaries[1])
    else:
        mask_i = ops.logical_or(x_i < boundaries[0], boundaries[1] < x_i)
    mask = ops.logical_and(mask, mask_i)

y_pred_cut = ops.cast(mask, dtype="float32")
y_pred_cut = ops.reshape(y_pred_cut, y_test.shape)
tp = ops.sum((y_pred_cut == 1) & (y_test == 1))
fp = ops.sum((y_pred_cut == 1) & (y_test == 0))
tn = ops.sum((y_pred_cut == 0) & (y_test == 0))
fn = ops.sum((y_pred_cut == 0) & (y_test == 1))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# True positives.......40148
# False positives.......1568
# Accuracy............0.8845
# Precision...........0.9624
# Significance.....1013.8902

# %%
# Analysis: learned cuts
for learned_cut in checkpoint.learned_cuts:
    print(learned_cut)
# Out:
# x1 < 0.0130
# x2 > -1.6795
# x7 < 377469.9062 or x7 > -682406.0625
# -5.1024 < x3 < 5.0594
# x5 < 6.2059
# x4 < -0.3153 or x4 > 0.3346
# x9 < 144681.0156

# %%
# Figure: learned cuts
show_learned_cuts(checkpoint, x_test, y_test, bins, feature_names_latex)

for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/learned_cut-{feature_names[i]}.pdf",
    )

# %%
# Figure: learned importance
show_learned_importance(checkpoint, feature_names_latex)

show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file="figures/learned_importance.pdf",
)
