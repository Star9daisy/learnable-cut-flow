# %%
# Configuration
import os
import sys

os.environ["KERAS_BACKEND"] = "jax"
sys.path.append("..")

# %%
# Setup
from importlib import import_module
from typing import cast

import numpy as np
from keras import ops
from keras.models import Model, load_model

from src.utils import (
    show_learned_cut,
    show_learned_cuts,
    show_learned_importance,
    show_record_dataset,
    show_record_dataset_correlation,
)

# %%
# Parameters

# Dataset
dataset_name = "real1"
n_samples = 200000
seed = 42

# Model
model_builder_name = "LearnableCutFlowParallel"
centers = [80, 0.15, 0.025, 2, 2, 0.3]
n_epochs = 200
batch_size = 512

# Figure
bins = 100
feature_names = ["mass", "c2_beta1", "c2_beta2", "d2_beta1", "d2_beta2", "tau21_beta1"]
feature_names_latex = [
    r"$M_{jet}$",
    r"$C_2^{\beta=1}$",
    r"$C_2^{\beta=2}$",
    r"$D_2^{\beta=1}$",
    r"$D_2^{\beta=2}$",
    r"$\tau_{21}^{\beta=1}$",
]

# %%
# Dataset
load_data = import_module(f"src.datasets.{dataset_name}").load_data
(x_train, y_train), (x_test, y_test) = load_data(n_samples, seed)

selection = np.ones_like(x_train[:, 0], dtype=bool)
for i in range(x_train.shape[1]):
    p05 = np.percentile(x_train[:, i], 5)
    p95 = np.percentile(x_train[:, i], 95)
    selection = (p05 < x_train[:, i]) & (x_train[:, i] < p95) & selection

x_train = x_train[selection]
y_train = y_train[selection]

selection = np.ones_like(x_test[:, 0], dtype=bool)
for i in range(x_test.shape[1]):
    p05 = np.percentile(x_test[:, i], 5)
    p95 = np.percentile(x_test[:, i], 95)
    selection = (p05 < x_test[:, i]) & (x_test[:, i] < p95) & selection

x_test = x_test[selection]
y_test = y_test[selection]

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")

# Figure: feature distribution
show_record_dataset(x_train, y_train, bins, feature_names_latex)

# Figure: feature correlation
show_record_dataset_correlation(x_train, feature_names_latex)
# Out:
# x_train.shape=(75549, 6)
# y_train.shape=(75549, 1)
# x_test.shape=(75436, 6)
# y_test.shape=(75436, 1)

# %%
# Model
ModelBuilder = getattr(import_module("src.models"), model_builder_name)
model = ModelBuilder(x_train.shape, centers, name="lcf_par")
model.normalization.adapt(x_train)
model.compile(optimizer="adam", loss="crossentropy")
model.fit(x_train, y_train, epochs=n_epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.3906
# Epoch 2/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.3740
# Epoch 3/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3594
# Epoch 4/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3473
# Epoch 5/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3370
# Epoch 6/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3285
# Epoch 7/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3212
# Epoch 8/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3153
# Epoch 9/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3109
# Epoch 10/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3073
# Epoch 11/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3037
# Epoch 12/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3010
# Epoch 13/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2994
# Epoch 14/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2980
# Epoch 15/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2973
# Epoch 16/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2966
# Epoch 17/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2956
# Epoch 18/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2948
# Epoch 19/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2937
# Epoch 20/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2937
# Epoch 21/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2940
# Epoch 22/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2925
# Epoch 23/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2927
# Epoch 24/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2926
# Epoch 25/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.2924
# Epoch 26/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2914
# Epoch 27/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2925
# Epoch 28/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2909
# Epoch 29/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.2920
# Epoch 30/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.2908
# Epoch 31/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2908
# Epoch 32/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2906
# Epoch 33/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2912
# Epoch 34/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2905
# Epoch 35/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2908
# Epoch 36/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2902
# Epoch 37/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2893
# Epoch 38/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2898
# Epoch 39/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2901
# Epoch 40/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2891
# Epoch 41/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2886
# Epoch 42/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2880
# Epoch 43/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2869
# Epoch 44/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2867
# Epoch 45/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2868
# Epoch 46/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2857
# Epoch 47/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2857
# Epoch 48/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2850
# Epoch 49/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2848
# Epoch 50/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2846
# Epoch 51/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2845
# Epoch 52/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2843
# Epoch 53/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2835
# Epoch 54/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2836
# Epoch 55/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2834
# Epoch 56/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2830
# Epoch 57/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2826
# Epoch 58/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2836
# Epoch 59/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.2833
# Epoch 60/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2829
# Epoch 61/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2825
# Epoch 62/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2828
# Epoch 63/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2826
# Epoch 64/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2824
# Epoch 65/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2818
# Epoch 66/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2822
# Epoch 67/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2825
# Epoch 68/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 69/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2822
# Epoch 70/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2823
# Epoch 71/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2818
# Epoch 72/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2824
# Epoch 73/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2815
# Epoch 74/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2815
# Epoch 75/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2824
# Epoch 76/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2813
# Epoch 77/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2816
# Epoch 78/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2812
# Epoch 79/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2828
# Epoch 80/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2812
# Epoch 81/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2813
# Epoch 82/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2816
# Epoch 83/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2813
# Epoch 84/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2811
# Epoch 85/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 86/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2820
# Epoch 87/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 88/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 89/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 90/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 91/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 92/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 93/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2809
# Epoch 94/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2810
# Epoch 95/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 96/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 97/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 98/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2817
# Epoch 99/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 100/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2806
# Epoch 101/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 102/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809
# Epoch 103/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2816
# Epoch 104/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2811
# Epoch 105/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.2818
# Epoch 106/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 107/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814
# Epoch 108/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2817
# Epoch 109/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2813
# Epoch 110/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2809
# Epoch 111/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2807
# Epoch 113/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 114/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2799
# Epoch 115/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2811
# Epoch 116/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2809
# Epoch 117/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2805
# Epoch 118/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 119/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2797
# Epoch 120/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2807
# Epoch 121/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809
# Epoch 122/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 124/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 125/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 126/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 127/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2808
# Epoch 128/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2798
# Epoch 129/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2805
# Epoch 130/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 131/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2812
# Epoch 132/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2800
# Epoch 133/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.2805
# Epoch 134/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809
# Epoch 135/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 137/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2813
# Epoch 138/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2803
# Epoch 139/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2802
# Epoch 140/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2808
# Epoch 141/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2800
# Epoch 142/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2796
# Epoch 143/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2815
# Epoch 144/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 145/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 146/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2807
# Epoch 147/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2808
# Epoch 148/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2808
# Epoch 150/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 151/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2813
# Epoch 152/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 153/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 154/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 155/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2803
# Epoch 156/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2796
# Epoch 157/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2804
# Epoch 158/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 159/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2803
# Epoch 160/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 161/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 162/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 163/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2800
# Epoch 164/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2800
# Epoch 165/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 166/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2798
# Epoch 167/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 168/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 169/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2796
# Epoch 170/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2803
# Epoch 171/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2802
# Epoch 172/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2799
# Epoch 173/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2800
# Epoch 174/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 175/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809
# Epoch 176/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810
# Epoch 177/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2798
# Epoch 178/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2800
# Epoch 180/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 181/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2803
# Epoch 182/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2796
# Epoch 183/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2795
# Epoch 184/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809
# Epoch 185/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2798
# Epoch 186/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 187/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2801
# Epoch 188/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2812
# Epoch 189/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2803
# Epoch 191/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 192/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2807
# Epoch 193/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2804
# Epoch 194/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 195/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2802
# Epoch 196/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2805
# Epoch 197/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2806
# Epoch 198/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2801
# Epoch 199/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2796
# Epoch 200/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2796

# %%
# Save model
checkpoint_name = f"exp-{dataset_name}-{model.name}"
model.save(f"checkpoints/{checkpoint_name}.keras")
checkpoint = cast(Model, load_model(f"checkpoints/{checkpoint_name}.keras"))

# %%
# Analysis: metrics
y_pred = checkpoint.predict(x_test, batch_size=batch_size)
y_true = y_test

tp = ops.sum((y_true == 1) & (y_pred == 1))
fp = ops.sum((y_true == 0) & (y_pred == 1))
tn = ops.sum((y_true == 0) & (y_pred == 0))
fn = ops.sum((y_true == 1) & (y_pred == 0))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step
# True positives.......28172
# False positives.......4007
# Accuracy............0.7313
# Precision...........0.8755
# Significance......445.0492

# %%
# Analysis: check metrics via learned cuts
mask = ops.ones_like(x_test[:, 0], dtype="bool")
n_features = x_test.shape[1]
selection = (
    checkpoint.learned_importance > 1 / n_features * checkpoint.importance_min_percent
)
for i, cut_report in enumerate(checkpoint.learned_cuts_report):
    if not selection[i]:
        continue

    x_i = x_test[:, i]
    boundaries = cut_report["boundaries"]
    index = cut_report["index"]

    if cut_report["case"] == "left":
        mask_i = x_i < boundaries[index]
    elif cut_report["case"] == "right":
        mask_i = x_i > boundaries[index]
    elif cut_report["case"] == "middle":
        mask_i = ops.logical_and(boundaries[0] < x_i, x_i < boundaries[1])
    else:
        mask_i = ops.logical_or(x_i < boundaries[0], boundaries[1] < x_i)
    mask = ops.logical_and(mask, mask_i)

y_pred_cut = ops.cast(mask, dtype="float32")
y_pred_cut = ops.reshape(y_pred_cut, y_test.shape)
tp = ops.sum((y_pred_cut == 1) & (y_test == 1))
fp = ops.sum((y_pred_cut == 1) & (y_test == 0))
tn = ops.sum((y_pred_cut == 0) & (y_test == 0))
fn = ops.sum((y_pred_cut == 0) & (y_test == 1))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# True positives.......28172
# False positives.......4007
# Accuracy............0.7313
# Precision...........0.8755
# Significance......445.0492

# %%
# Analysis: learned cuts
for learned_cut in checkpoint.learned_cuts:
    print(learned_cut)
# Out:
# x1 > 56.1591
# 0.0669 < x2 < 0.2132
# 0.0068 < x3 < 0.1251
# x4 < 1.5384
# x5 < 1.3521
# x6 < 0.7186

# %%
# Figure: learned cuts
show_learned_cuts(checkpoint, x_test, y_test, bins, feature_names_latex)

# Save in png and pdf
for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_cut_{i + 1}.png",
    )
for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_cut_{i + 1}.pdf",
    )

# %%
# Figure: learned importance
show_learned_importance(checkpoint, feature_names_latex)

# Save in png and pdf
show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_importance.png",
)
show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_importance.pdf",
)
