# %%
# System
import os
import sys

os.environ["KERAS_BACKEND"] = "jax"
sys.path.append("../..")

# %%
# Setup
from importlib import import_module
from pathlib import Path
from time import time
from typing import cast

import numpy as np
import pandas as pd
from keras import ops
from src.callbacks import ImportanceUpdate
from src.models import LearnableCutFlowModel, LearnableCutFlowSequentialModel
from src.utils import (
    load_model,
    plot_learned_cut,
    plot_learned_importance,
    print,
    tex_to_str,
)

# %%
# Parameters
n_runs = 10

# Dataset
dataset = "real1"  # *
n_samples = 200000
seed = 42

# Model
model_builder = "LearnableCutFlowParallel"  # *
centers = [80, 0.15, 0.025, 2, 2, 0.3]  # *
n_epochs = 200
batch_size = 512

# Figure *
features = [
    r"$M_{jet}$",
    r"$C_2^{\beta=1}$",
    r"$C_2^{\beta=2}$",
    r"$D_2^{\beta=1}$",
    r"$D_2^{\beta=2}$",
    r"$\tau_{21}^{\beta=1}$",
]
bins = 100

# Directory
FIGURES_DIR = Path("figures")
CHECKPOINTS_DIR = Path("checkpoints")

FIGURES_DIR.mkdir(exist_ok=True)
CHECKPOINTS_DIR.mkdir(exist_ok=True)

# %%
# Dataset
module = import_module(f"src.datasets.{dataset}")
load_data = getattr(module, "load_data")
(x_train, y_train), (x_test, y_test) = load_data(n_samples, seed)

selection = np.ones_like(x_train[:, 0], dtype=bool)
for i in range(x_train.shape[1]):
    p05 = np.percentile(x_train[:, i], 5)
    p95 = np.percentile(x_train[:, i], 95)
    selection = (p05 < x_train[:, i]) & (x_train[:, i] < p95) & selection
x_train = x_train[selection]
y_train = y_train[selection]

selection = np.ones_like(x_test[:, 0], dtype=bool)
for i in range(x_test.shape[1]):
    p05 = np.percentile(x_test[:, i], 5)
    p95 = np.percentile(x_test[:, i], 95)
    selection = (p05 < x_test[:, i]) & (x_test[:, i] < p95) & selection
x_test = x_test[selection]
y_test = y_test[selection]

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")
# Out:
# x_train.shape=(75549, 6)
# y_train.shape=(75549, 1)
# x_test.shape=(75436, 6)
# y_test.shape=(75436, 1)

# %%
# Model
training_time = []

for i in range(n_runs):
    print(f"Training model {i + 1} of {n_runs}")

    ModelBuilder = getattr(import_module("src.models"), model_builder)
    model = ModelBuilder(x_train.shape, centers, features=features, name="lcf_par")
    model = cast(LearnableCutFlowModel, model)

    model.adapt(x_train)
    model.compile(optimizer="adam", loss="crossentropy")

    start_time = time()
    model.fit(
        x_train,
        y_train,
        epochs=n_epochs,
        batch_size=batch_size,
        callbacks=[ImportanceUpdate(model)],
        verbose=2,
    )
    training_time.append(time() - start_time)

    model.save(CHECKPOINTS_DIR / f"model@{i + 1}.keras")

training_time_mean = np.mean(training_time)
training_time_std = np.std(training_time)

print(f"\n\nTraining time: {training_time_mean:.2f} ± {training_time_std:.2f} seconds")
# Out:
# Training model 1 of 10
# Epoch 1/200
# 148/148 - 8s - 51ms/step - loss: 0.3487
# Epoch 2/200
# 148/148 - 2s - 13ms/step - loss: 0.3381
# Epoch 3/200
# 148/148 - 0s - 2ms/step - loss: 0.3301
# Epoch 4/200
# 148/148 - 0s - 1ms/step - loss: 0.3241
# Epoch 5/200
# 148/148 - 0s - 2ms/step - loss: 0.3196
# Epoch 6/200
# 148/148 - 0s - 1ms/step - loss: 0.3162
# Epoch 7/200
# 148/148 - 0s - 2ms/step - loss: 0.3134
# Epoch 8/200
# 148/148 - 0s - 2ms/step - loss: 0.3108
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3081
# Epoch 10/200
# 148/148 - 0s - 2ms/step - loss: 0.3052
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.3026
# Epoch 12/200
# 148/148 - 0s - 1ms/step - loss: 0.3003
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.2985
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2972
# Epoch 15/200
# 148/148 - 0s - 1ms/step - loss: 0.2961
# Epoch 16/200
# 148/148 - 0s - 2ms/step - loss: 0.2952
# Epoch 17/200
# 148/148 - 0s - 2ms/step - loss: 0.2945
# Epoch 18/200
# 148/148 - 0s - 1ms/step - loss: 0.2939
# Epoch 19/200
# 148/148 - 0s - 2ms/step - loss: 0.2934
# Epoch 20/200
# 148/148 - 0s - 2ms/step - loss: 0.2929
# Epoch 21/200
# 148/148 - 0s - 2ms/step - loss: 0.2925
# Epoch 22/200
# 148/148 - 0s - 1ms/step - loss: 0.2921
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2918
# Epoch 24/200
# 148/148 - 0s - 2ms/step - loss: 0.2915
# Epoch 25/200
# 148/148 - 0s - 2ms/step - loss: 0.2912
# Epoch 26/200
# 148/148 - 0s - 1ms/step - loss: 0.2908
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2905
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2901
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2897
# Epoch 30/200
# 148/148 - 0s - 1ms/step - loss: 0.2893
# Epoch 31/200
# 148/148 - 0s - 2ms/step - loss: 0.2888
# Epoch 32/200
# 148/148 - 0s - 2ms/step - loss: 0.2883
# Epoch 33/200
# 148/148 - 0s - 2ms/step - loss: 0.2879
# Epoch 34/200
# 148/148 - 0s - 2ms/step - loss: 0.2875
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2872
# Epoch 36/200
# 148/148 - 0s - 2ms/step - loss: 0.2869
# Epoch 37/200
# 148/148 - 0s - 2ms/step - loss: 0.2866
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2864
# Epoch 39/200
# 148/148 - 0s - 1ms/step - loss: 0.2862
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2859
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2858
# Epoch 42/200
# 148/148 - 0s - 2ms/step - loss: 0.2856
# Epoch 43/200
# 148/148 - 0s - 2ms/step - loss: 0.2854
# Epoch 44/200
# 148/148 - 0s - 2ms/step - loss: 0.2853
# Epoch 45/200
# 148/148 - 0s - 2ms/step - loss: 0.2851
# Epoch 46/200
# 148/148 - 0s - 2ms/step - loss: 0.2850
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2849
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2848
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2847
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2846
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2845
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2844
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2843
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2841
# Epoch 55/200
# 148/148 - 0s - 2ms/step - loss: 0.2840
# Epoch 56/200
# 148/148 - 0s - 2ms/step - loss: 0.2838
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2836
# Epoch 58/200
# 148/148 - 0s - 2ms/step - loss: 0.2833
# Epoch 59/200
# 148/148 - 0s - 2ms/step - loss: 0.2831
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2827
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 63/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 65/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 70/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 71/200
# 148/148 - 0s - 1ms/step - loss: 0.2819
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 73/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 74/200
# 148/148 - 0s - 1ms/step - loss: 0.2817
# Epoch 75/200
# 148/148 - 0s - 1ms/step - loss: 0.2817
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 77/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 78/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 79/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 80/200
# 148/148 - 0s - 1ms/step - loss: 0.2814
# Epoch 81/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 84/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 88/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 89/200
# 148/148 - 0s - 1ms/step - loss: 0.2811
# Epoch 90/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 92/200
# 148/148 - 0s - 1ms/step - loss: 0.2810
# Epoch 93/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 102/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 112/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 113/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 115/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 119/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 120/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 121/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 122/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 124/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 125/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 126/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 127/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 128/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 129/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 130/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 131/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 143/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 144/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 145/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 146/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 147/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 152/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 153/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 154/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 155/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 182/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 183/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 184/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 185/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 186/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 187/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 188/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 195/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 196/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 200/200
# 148/148 - 0s - 1ms/step - loss: 0.2803
# Training model 2 of 10
# Epoch 1/200
# 148/148 - 6s - 42ms/step - loss: 0.3506
# Epoch 2/200
# 148/148 - 2s - 14ms/step - loss: 0.3397
# Epoch 3/200
# 148/148 - 0s - 2ms/step - loss: 0.3314
# Epoch 4/200
# 148/148 - 0s - 1ms/step - loss: 0.3249
# Epoch 5/200
# 148/148 - 0s - 1ms/step - loss: 0.3194
# Epoch 6/200
# 148/148 - 0s - 2ms/step - loss: 0.3146
# Epoch 7/200
# 148/148 - 0s - 2ms/step - loss: 0.3105
# Epoch 8/200
# 148/148 - 0s - 2ms/step - loss: 0.3071
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3044
# Epoch 10/200
# 148/148 - 0s - 2ms/step - loss: 0.3023
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.3006
# Epoch 12/200
# 148/148 - 0s - 2ms/step - loss: 0.2994
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.2983
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2975
# Epoch 15/200
# 148/148 - 0s - 2ms/step - loss: 0.2968
# Epoch 16/200
# 148/148 - 0s - 2ms/step - loss: 0.2962
# Epoch 17/200
# 148/148 - 0s - 2ms/step - loss: 0.2956
# Epoch 18/200
# 148/148 - 0s - 2ms/step - loss: 0.2951
# Epoch 19/200
# 148/148 - 0s - 2ms/step - loss: 0.2945
# Epoch 20/200
# 148/148 - 0s - 2ms/step - loss: 0.2940
# Epoch 21/200
# 148/148 - 0s - 2ms/step - loss: 0.2934
# Epoch 22/200
# 148/148 - 0s - 1ms/step - loss: 0.2929
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2923
# Epoch 24/200
# 148/148 - 0s - 1ms/step - loss: 0.2918
# Epoch 25/200
# 148/148 - 0s - 2ms/step - loss: 0.2913
# Epoch 26/200
# 148/148 - 0s - 2ms/step - loss: 0.2908
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2903
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2898
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2894
# Epoch 30/200
# 148/148 - 0s - 2ms/step - loss: 0.2890
# Epoch 31/200
# 148/148 - 0s - 2ms/step - loss: 0.2886
# Epoch 32/200
# 148/148 - 0s - 1ms/step - loss: 0.2882
# Epoch 33/200
# 148/148 - 0s - 1ms/step - loss: 0.2879
# Epoch 34/200
# 148/148 - 0s - 2ms/step - loss: 0.2875
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2872
# Epoch 36/200
# 148/148 - 0s - 1ms/step - loss: 0.2869
# Epoch 37/200
# 148/148 - 0s - 1ms/step - loss: 0.2867
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2864
# Epoch 39/200
# 148/148 - 0s - 2ms/step - loss: 0.2862
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2859
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2857
# Epoch 42/200
# 148/148 - 0s - 2ms/step - loss: 0.2854
# Epoch 43/200
# 148/148 - 0s - 2ms/step - loss: 0.2852
# Epoch 44/200
# 148/148 - 0s - 1ms/step - loss: 0.2849
# Epoch 45/200
# 148/148 - 0s - 1ms/step - loss: 0.2846
# Epoch 46/200
# 148/148 - 0s - 1ms/step - loss: 0.2843
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2841
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2838
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2836
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2834
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2833
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2831
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2830
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 55/200
# 148/148 - 0s - 2ms/step - loss: 0.2827
# Epoch 56/200
# 148/148 - 0s - 1ms/step - loss: 0.2826
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 58/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 59/200
# 148/148 - 0s - 1ms/step - loss: 0.2823
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 63/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 65/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 70/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 71/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 73/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 74/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 75/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 77/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 78/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 79/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 80/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 81/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 84/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 88/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 89/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 90/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 92/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 93/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 102/200
# 148/148 - 0s - 1ms/step - loss: 0.2808
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 113/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 115/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 119/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 120/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 121/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 122/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 124/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 125/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 126/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 127/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 128/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 129/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 130/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 131/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 143/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 144/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 145/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 146/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 147/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 152/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 153/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 154/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 155/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 182/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 183/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 184/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 185/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 186/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 187/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 188/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 195/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 196/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 200/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Training model 3 of 10
# Epoch 1/200
# 148/148 - 6s - 43ms/step - loss: 0.3514
# Epoch 2/200
# 148/148 - 2s - 14ms/step - loss: 0.3388
# Epoch 3/200
# 148/148 - 0s - 2ms/step - loss: 0.3289
# Epoch 4/200
# 148/148 - 0s - 2ms/step - loss: 0.3214
# Epoch 5/200
# 148/148 - 0s - 2ms/step - loss: 0.3156
# Epoch 6/200
# 148/148 - 0s - 2ms/step - loss: 0.3112
# Epoch 7/200
# 148/148 - 0s - 2ms/step - loss: 0.3077
# Epoch 8/200
# 148/148 - 0s - 2ms/step - loss: 0.3049
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3027
# Epoch 10/200
# 148/148 - 0s - 2ms/step - loss: 0.3009
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.2995
# Epoch 12/200
# 148/148 - 0s - 2ms/step - loss: 0.2982
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.2972
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2962
# Epoch 15/200
# 148/148 - 0s - 2ms/step - loss: 0.2954
# Epoch 16/200
# 148/148 - 0s - 2ms/step - loss: 0.2947
# Epoch 17/200
# 148/148 - 0s - 2ms/step - loss: 0.2941
# Epoch 18/200
# 148/148 - 0s - 2ms/step - loss: 0.2936
# Epoch 19/200
# 148/148 - 0s - 2ms/step - loss: 0.2931
# Epoch 20/200
# 148/148 - 0s - 2ms/step - loss: 0.2926
# Epoch 21/200
# 148/148 - 0s - 2ms/step - loss: 0.2922
# Epoch 22/200
# 148/148 - 0s - 1ms/step - loss: 0.2919
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2915
# Epoch 24/200
# 148/148 - 0s - 2ms/step - loss: 0.2911
# Epoch 25/200
# 148/148 - 0s - 2ms/step - loss: 0.2908
# Epoch 26/200
# 148/148 - 0s - 2ms/step - loss: 0.2905
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2901
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2898
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2895
# Epoch 30/200
# 148/148 - 0s - 2ms/step - loss: 0.2892
# Epoch 31/200
# 148/148 - 0s - 2ms/step - loss: 0.2888
# Epoch 32/200
# 148/148 - 0s - 2ms/step - loss: 0.2885
# Epoch 33/200
# 148/148 - 0s - 2ms/step - loss: 0.2882
# Epoch 34/200
# 148/148 - 0s - 2ms/step - loss: 0.2879
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2876
# Epoch 36/200
# 148/148 - 0s - 2ms/step - loss: 0.2873
# Epoch 37/200
# 148/148 - 0s - 2ms/step - loss: 0.2871
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2868
# Epoch 39/200
# 148/148 - 0s - 2ms/step - loss: 0.2865
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2863
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2860
# Epoch 42/200
# 148/148 - 0s - 2ms/step - loss: 0.2858
# Epoch 43/200
# 148/148 - 0s - 2ms/step - loss: 0.2855
# Epoch 44/200
# 148/148 - 0s - 2ms/step - loss: 0.2852
# Epoch 45/200
# 148/148 - 0s - 2ms/step - loss: 0.2849
# Epoch 46/200
# 148/148 - 0s - 2ms/step - loss: 0.2846
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2843
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2841
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2838
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2836
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2835
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2833
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2832
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2830
# Epoch 55/200
# 148/148 - 0s - 2ms/step - loss: 0.2829
# Epoch 56/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2827
# Epoch 58/200
# 148/148 - 0s - 2ms/step - loss: 0.2826
# Epoch 59/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 63/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 65/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 70/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 71/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 73/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 74/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 75/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 77/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 78/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 79/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 80/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 81/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 84/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 88/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 89/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 90/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 92/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 93/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 99/200
# 148/148 - 0s - 1ms/step - loss: 0.2807
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 102/200
# 148/148 - 0s - 1ms/step - loss: 0.2807
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 105/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 107/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 111/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 113/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 115/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 119/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 120/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 121/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 122/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 124/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 125/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 126/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 127/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 128/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 129/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 130/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 131/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 143/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 144/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 145/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 146/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 147/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 149/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 152/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 153/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 154/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 155/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 179/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 182/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 183/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 184/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 185/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 186/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 187/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 188/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 195/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 196/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 200/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Training model 4 of 10
# Epoch 1/200
# 148/148 - 7s - 45ms/step - loss: 0.3835
# Epoch 2/200
# 148/148 - 2s - 16ms/step - loss: 0.3668
# Epoch 3/200
# 148/148 - 0s - 2ms/step - loss: 0.3534
# Epoch 4/200
# 148/148 - 0s - 2ms/step - loss: 0.3425
# Epoch 5/200
# 148/148 - 0s - 2ms/step - loss: 0.3337
# Epoch 6/200
# 148/148 - 0s - 2ms/step - loss: 0.3266
# Epoch 7/200
# 148/148 - 0s - 2ms/step - loss: 0.3211
# Epoch 8/200
# 148/148 - 0s - 2ms/step - loss: 0.3167
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3131
# Epoch 10/200
# 148/148 - 0s - 2ms/step - loss: 0.3099
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.3067
# Epoch 12/200
# 148/148 - 0s - 2ms/step - loss: 0.3035
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.3007
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2986
# Epoch 15/200
# 148/148 - 0s - 2ms/step - loss: 0.2970
# Epoch 16/200
# 148/148 - 0s - 2ms/step - loss: 0.2958
# Epoch 17/200
# 148/148 - 0s - 2ms/step - loss: 0.2949
# Epoch 18/200
# 148/148 - 0s - 2ms/step - loss: 0.2942
# Epoch 19/200
# 148/148 - 0s - 2ms/step - loss: 0.2936
# Epoch 20/200
# 148/148 - 0s - 1ms/step - loss: 0.2931
# Epoch 21/200
# 148/148 - 0s - 1ms/step - loss: 0.2926
# Epoch 22/200
# 148/148 - 0s - 1ms/step - loss: 0.2922
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2918
# Epoch 24/200
# 148/148 - 0s - 1ms/step - loss: 0.2914
# Epoch 25/200
# 148/148 - 0s - 2ms/step - loss: 0.2910
# Epoch 26/200
# 148/148 - 0s - 2ms/step - loss: 0.2906
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2902
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2898
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2894
# Epoch 30/200
# 148/148 - 0s - 1ms/step - loss: 0.2891
# Epoch 31/200
# 148/148 - 0s - 2ms/step - loss: 0.2887
# Epoch 32/200
# 148/148 - 0s - 2ms/step - loss: 0.2883
# Epoch 33/200
# 148/148 - 0s - 2ms/step - loss: 0.2880
# Epoch 34/200
# 148/148 - 0s - 2ms/step - loss: 0.2876
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2873
# Epoch 36/200
# 148/148 - 0s - 2ms/step - loss: 0.2870
# Epoch 37/200
# 148/148 - 0s - 2ms/step - loss: 0.2867
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2864
# Epoch 39/200
# 148/148 - 0s - 2ms/step - loss: 0.2861
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2858
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2855
# Epoch 42/200
# 148/148 - 0s - 2ms/step - loss: 0.2853
# Epoch 43/200
# 148/148 - 0s - 2ms/step - loss: 0.2850
# Epoch 44/200
# 148/148 - 0s - 2ms/step - loss: 0.2848
# Epoch 45/200
# 148/148 - 0s - 2ms/step - loss: 0.2846
# Epoch 46/200
# 148/148 - 0s - 2ms/step - loss: 0.2844
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2842
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2840
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2838
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2836
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2835
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2833
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2832
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2831
# Epoch 55/200
# 148/148 - 0s - 2ms/step - loss: 0.2830
# Epoch 56/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2827
# Epoch 58/200
# 148/148 - 0s - 2ms/step - loss: 0.2826
# Epoch 59/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 63/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 65/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 70/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 71/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 73/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 74/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 75/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 77/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 78/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 79/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 80/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 81/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 84/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 88/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 89/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 90/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 92/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 93/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 102/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 106/200
# 148/148 - 0s - 1ms/step - loss: 0.2808
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 112/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 113/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 115/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 119/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 120/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 121/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 122/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 124/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 125/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 126/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 127/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 128/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 129/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 130/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 131/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 143/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 144/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 145/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 146/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 147/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 152/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 153/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 154/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 155/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 182/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 183/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 184/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 185/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 186/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 187/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 188/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 195/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 196/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 200/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Training model 5 of 10
# Epoch 1/200
# 148/148 - 7s - 46ms/step - loss: 0.3520
# Epoch 2/200
# 148/148 - 2s - 16ms/step - loss: 0.3408
# Epoch 3/200
# 148/148 - 0s - 2ms/step - loss: 0.3324
# Epoch 4/200
# 148/148 - 0s - 2ms/step - loss: 0.3262
# Epoch 5/200
# 148/148 - 0s - 2ms/step - loss: 0.3216
# Epoch 6/200
# 148/148 - 0s - 2ms/step - loss: 0.3182
# Epoch 7/200
# 148/148 - 0s - 2ms/step - loss: 0.3156
# Epoch 8/200
# 148/148 - 0s - 2ms/step - loss: 0.3135
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3114
# Epoch 10/200
# 148/148 - 0s - 2ms/step - loss: 0.3090
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.3062
# Epoch 12/200
# 148/148 - 0s - 2ms/step - loss: 0.3033
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.3008
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2988
# Epoch 15/200
# 148/148 - 0s - 1ms/step - loss: 0.2973
# Epoch 16/200
# 148/148 - 0s - 2ms/step - loss: 0.2962
# Epoch 17/200
# 148/148 - 0s - 2ms/step - loss: 0.2952
# Epoch 18/200
# 148/148 - 0s - 2ms/step - loss: 0.2945
# Epoch 19/200
# 148/148 - 0s - 2ms/step - loss: 0.2939
# Epoch 20/200
# 148/148 - 0s - 2ms/step - loss: 0.2933
# Epoch 21/200
# 148/148 - 0s - 2ms/step - loss: 0.2928
# Epoch 22/200
# 148/148 - 0s - 2ms/step - loss: 0.2924
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2919
# Epoch 24/200
# 148/148 - 0s - 2ms/step - loss: 0.2915
# Epoch 25/200
# 148/148 - 0s - 2ms/step - loss: 0.2911
# Epoch 26/200
# 148/148 - 0s - 2ms/step - loss: 0.2907
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2904
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2900
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2897
# Epoch 30/200
# 148/148 - 0s - 2ms/step - loss: 0.2894
# Epoch 31/200
# 148/148 - 0s - 2ms/step - loss: 0.2891
# Epoch 32/200
# 148/148 - 0s - 2ms/step - loss: 0.2889
# Epoch 33/200
# 148/148 - 0s - 2ms/step - loss: 0.2886
# Epoch 34/200
# 148/148 - 0s - 2ms/step - loss: 0.2884
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2881
# Epoch 36/200
# 148/148 - 0s - 2ms/step - loss: 0.2879
# Epoch 37/200
# 148/148 - 0s - 2ms/step - loss: 0.2876
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2874
# Epoch 39/200
# 148/148 - 0s - 2ms/step - loss: 0.2870
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2867
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2862
# Epoch 42/200
# 148/148 - 0s - 2ms/step - loss: 0.2858
# Epoch 43/200
# 148/148 - 0s - 2ms/step - loss: 0.2854
# Epoch 44/200
# 148/148 - 0s - 2ms/step - loss: 0.2850
# Epoch 45/200
# 148/148 - 0s - 2ms/step - loss: 0.2847
# Epoch 46/200
# 148/148 - 0s - 2ms/step - loss: 0.2844
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2842
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2839
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2837
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2835
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2834
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2832
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2830
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2829
# Epoch 55/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 56/200
# 148/148 - 0s - 2ms/step - loss: 0.2826
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2825
# Epoch 58/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 59/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2822
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 63/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 65/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2816
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2815
# Epoch 70/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 71/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 73/200
# 148/148 - 0s - 2ms/step - loss: 0.2813
# Epoch 74/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 75/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 77/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 78/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 79/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 80/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 81/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 84/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 88/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 89/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 90/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 92/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 93/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 102/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 113/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 114/200
# ...
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 102/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 103/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 104/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 108/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 109/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 113/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 115/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 119/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 120/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 121/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 122/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 124/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 125/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 126/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 127/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 128/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 129/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 130/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 131/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 143/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 144/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 145/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 146/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 147/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 152/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 153/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 154/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 155/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 182/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 183/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 184/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 185/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 186/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 187/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 188/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 195/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 196/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 200/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Training model 10 of 10
# Epoch 1/200
# 148/148 - 6s - 41ms/step - loss: 0.3789
# Epoch 2/200
# 148/148 - 2s - 16ms/step - loss: 0.3631
# Epoch 3/200
# 148/148 - 0s - 1ms/step - loss: 0.3501
# Epoch 4/200
# 148/148 - 0s - 2ms/step - loss: 0.3395
# Epoch 5/200
# 148/148 - 0s - 2ms/step - loss: 0.3308
# Epoch 6/200
# 148/148 - 0s - 2ms/step - loss: 0.3236
# Epoch 7/200
# 148/148 - 0s - 1ms/step - loss: 0.3178
# Epoch 8/200
# 148/148 - 0s - 1ms/step - loss: 0.3130
# Epoch 9/200
# 148/148 - 0s - 2ms/step - loss: 0.3091
# Epoch 10/200
# 148/148 - 0s - 1ms/step - loss: 0.3059
# Epoch 11/200
# 148/148 - 0s - 2ms/step - loss: 0.3033
# Epoch 12/200
# 148/148 - 0s - 2ms/step - loss: 0.3012
# Epoch 13/200
# 148/148 - 0s - 2ms/step - loss: 0.2994
# Epoch 14/200
# 148/148 - 0s - 2ms/step - loss: 0.2980
# Epoch 15/200
# 148/148 - 0s - 2ms/step - loss: 0.2968
# Epoch 16/200
# 148/148 - 0s - 1ms/step - loss: 0.2958
# Epoch 17/200
# 148/148 - 0s - 1ms/step - loss: 0.2950
# Epoch 18/200
# 148/148 - 0s - 1ms/step - loss: 0.2942
# Epoch 19/200
# 148/148 - 0s - 1ms/step - loss: 0.2936
# Epoch 20/200
# 148/148 - 0s - 2ms/step - loss: 0.2931
# Epoch 21/200
# 148/148 - 0s - 2ms/step - loss: 0.2926
# Epoch 22/200
# 148/148 - 0s - 1ms/step - loss: 0.2922
# Epoch 23/200
# 148/148 - 0s - 2ms/step - loss: 0.2918
# Epoch 24/200
# 148/148 - 0s - 1ms/step - loss: 0.2914
# Epoch 25/200
# 148/148 - 0s - 1ms/step - loss: 0.2910
# Epoch 26/200
# 148/148 - 0s - 1ms/step - loss: 0.2906
# Epoch 27/200
# 148/148 - 0s - 2ms/step - loss: 0.2902
# Epoch 28/200
# 148/148 - 0s - 2ms/step - loss: 0.2899
# Epoch 29/200
# 148/148 - 0s - 2ms/step - loss: 0.2895
# Epoch 30/200
# 148/148 - 0s - 1ms/step - loss: 0.2892
# Epoch 31/200
# 148/148 - 0s - 1ms/step - loss: 0.2889
# Epoch 32/200
# 148/148 - 0s - 1ms/step - loss: 0.2886
# Epoch 33/200
# 148/148 - 0s - 2ms/step - loss: 0.2883
# Epoch 34/200
# 148/148 - 0s - 1ms/step - loss: 0.2880
# Epoch 35/200
# 148/148 - 0s - 2ms/step - loss: 0.2877
# Epoch 36/200
# 148/148 - 0s - 2ms/step - loss: 0.2874
# Epoch 37/200
# 148/148 - 0s - 2ms/step - loss: 0.2870
# Epoch 38/200
# 148/148 - 0s - 2ms/step - loss: 0.2867
# Epoch 39/200
# 148/148 - 0s - 2ms/step - loss: 0.2864
# Epoch 40/200
# 148/148 - 0s - 2ms/step - loss: 0.2861
# Epoch 41/200
# 148/148 - 0s - 2ms/step - loss: 0.2858
# Epoch 42/200
# 148/148 - 0s - 1ms/step - loss: 0.2855
# Epoch 43/200
# 148/148 - 0s - 1ms/step - loss: 0.2852
# Epoch 44/200
# 148/148 - 0s - 1ms/step - loss: 0.2849
# Epoch 45/200
# 148/148 - 0s - 2ms/step - loss: 0.2847
# Epoch 46/200
# 148/148 - 0s - 1ms/step - loss: 0.2844
# Epoch 47/200
# 148/148 - 0s - 2ms/step - loss: 0.2842
# Epoch 48/200
# 148/148 - 0s - 2ms/step - loss: 0.2840
# Epoch 49/200
# 148/148 - 0s - 2ms/step - loss: 0.2838
# Epoch 50/200
# 148/148 - 0s - 2ms/step - loss: 0.2836
# Epoch 51/200
# 148/148 - 0s - 2ms/step - loss: 0.2835
# Epoch 52/200
# 148/148 - 0s - 2ms/step - loss: 0.2833
# Epoch 53/200
# 148/148 - 0s - 2ms/step - loss: 0.2832
# Epoch 54/200
# 148/148 - 0s - 2ms/step - loss: 0.2830
# Epoch 55/200
# 148/148 - 0s - 1ms/step - loss: 0.2829
# Epoch 56/200
# 148/148 - 0s - 2ms/step - loss: 0.2828
# Epoch 57/200
# 148/148 - 0s - 2ms/step - loss: 0.2827
# Epoch 58/200
# 148/148 - 0s - 1ms/step - loss: 0.2826
# Epoch 59/200
# 148/148 - 0s - 1ms/step - loss: 0.2825
# Epoch 60/200
# 148/148 - 0s - 2ms/step - loss: 0.2824
# Epoch 61/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 62/200
# 148/148 - 0s - 2ms/step - loss: 0.2823
# Epoch 63/200
# 148/148 - 0s - 1ms/step - loss: 0.2822
# Epoch 64/200
# 148/148 - 0s - 2ms/step - loss: 0.2821
# Epoch 65/200
# 148/148 - 0s - 1ms/step - loss: 0.2821
# Epoch 66/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 67/200
# 148/148 - 0s - 2ms/step - loss: 0.2820
# Epoch 68/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 69/200
# 148/148 - 0s - 2ms/step - loss: 0.2819
# Epoch 70/200
# 148/148 - 0s - 1ms/step - loss: 0.2819
# Epoch 71/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 72/200
# 148/148 - 0s - 2ms/step - loss: 0.2818
# Epoch 73/200
# 148/148 - 0s - 1ms/step - loss: 0.2818
# Epoch 74/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 75/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 76/200
# 148/148 - 0s - 2ms/step - loss: 0.2817
# Epoch 77/200
# 148/148 - 0s - 1ms/step - loss: 0.2817
# Epoch 78/200
# 148/148 - 0s - 1ms/step - loss: 0.2816
# Epoch 79/200
# 148/148 - 0s - 1ms/step - loss: 0.2816
# Epoch 80/200
# 148/148 - 0s - 1ms/step - loss: 0.2815
# Epoch 81/200
# 148/148 - 0s - 1ms/step - loss: 0.2815
# Epoch 82/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 83/200
# 148/148 - 0s - 2ms/step - loss: 0.2814
# Epoch 84/200
# 148/148 - 0s - 1ms/step - loss: 0.2813
# Epoch 85/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 86/200
# 148/148 - 0s - 2ms/step - loss: 0.2812
# Epoch 87/200
# 148/148 - 0s - 2ms/step - loss: 0.2811
# Epoch 88/200
# 148/148 - 0s - 1ms/step - loss: 0.2811
# Epoch 89/200
# 148/148 - 0s - 2ms/step - loss: 0.2810
# Epoch 90/200
# 148/148 - 0s - 1ms/step - loss: 0.2810
# Epoch 91/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 92/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 93/200
# 148/148 - 0s - 1ms/step - loss: 0.2809
# Epoch 94/200
# 148/148 - 0s - 2ms/step - loss: 0.2809
# Epoch 95/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 96/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 97/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 98/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 99/200
# 148/148 - 0s - 2ms/step - loss: 0.2808
# Epoch 100/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 101/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 102/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 103/200
# 148/148 - 0s - 1ms/step - loss: 0.2807
# Epoch 104/200
# 148/148 - 0s - 1ms/step - loss: 0.2807
# Epoch 105/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 106/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 107/200
# 148/148 - 0s - 2ms/step - loss: 0.2807
# Epoch 108/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 109/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 110/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 111/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 112/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 113/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 114/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 115/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 116/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 117/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 118/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 119/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 120/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 121/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 122/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 123/200
# 148/148 - 0s - 2ms/step - loss: 0.2806
# Epoch 124/200
# 148/148 - 0s - 1ms/step - loss: 0.2806
# Epoch 125/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 126/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 127/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 128/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 129/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 130/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 131/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 132/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 133/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 134/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 135/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 136/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 137/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 138/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 139/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 140/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 141/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 142/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 143/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 144/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 145/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 146/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 147/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 148/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 149/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 150/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 151/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 152/200
# 148/148 - 0s - 1ms/step - loss: 0.2805
# Epoch 153/200
# 148/148 - 0s - 2ms/step - loss: 0.2805
# Epoch 154/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 155/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 156/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 157/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 158/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 159/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 160/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 161/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 162/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 163/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 164/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 165/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 166/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 167/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 168/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 169/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 170/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 171/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 172/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 173/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 174/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 175/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 176/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 177/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 178/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 179/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 180/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 181/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 182/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 183/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 184/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 185/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 186/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 187/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 188/200
# 148/148 - 0s - 1ms/step - loss: 0.2804
# Epoch 189/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 190/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 191/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 192/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 193/200
# 148/148 - 0s - 2ms/step - loss: 0.2804
# Epoch 194/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 195/200
# 148/148 - 0s - 1ms/step - loss: 0.2803
# Epoch 196/200
# 148/148 - 0s - 1ms/step - loss: 0.2803
# Epoch 197/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 198/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 199/200
# 148/148 - 0s - 2ms/step - loss: 0.2803
# Epoch 200/200
# 148/148 - 0s - 1ms/step - loss: 0.2803
#
#
# Training time: 60.05 ± 2.22 seconds

# %%
# Checkpoint
checkpoints = [
    load_model(CHECKPOINTS_DIR / f"model@{i + 1}.keras") for i in range(n_runs)
]
checkpoints = [cast(LearnableCutFlowModel, i) for i in checkpoints]

# %%
# Analysis: metrics (x10)
tp_list = []
fp_list = []
accuracy_list = []
precision_list = []
significance_list = []

for checkpoint in checkpoints:
    y_pred = checkpoint.predict(x_test, batch_size=batch_size, verbose=0)
    y_true = y_test

    tp = ops.sum((y_true == 1) & (y_pred == 1))
    fp = ops.sum((y_true == 0) & (y_pred == 1))
    tn = ops.sum((y_true == 0) & (y_pred == 0))
    fn = ops.sum((y_true == 1) & (y_pred == 0))

    accuracy = (tp + tn) / (tp + tn + fp + fn)  # type: ignore
    precision = tp / (tp + fp)  # type: ignore
    significance = tp / ops.sqrt(fp)  # type: ignore

    tp_list.append(tp)
    fp_list.append(fp)
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    significance_list.append(significance)

tp_mean = ops.mean(tp_list)
tp_std = ops.std(tp_list)
fp_mean = ops.mean(fp_list)
fp_std = ops.std(fp_list)
accuracy_mean = ops.mean(accuracy_list)
accuracy_std = ops.std(accuracy_list)
precision_mean = ops.mean(precision_list)
precision_std = ops.std(precision_list)
significance_mean = ops.mean(significance_list)
significance_std = ops.std(significance_list)

print(f"True positives....{tp_mean:.2f} ± {tp_std:.2f}")
print(f"False positives...{fp_mean:.2f} ± {fp_std:.2f}")
print(f"Accuracy..........{accuracy_mean:.4f} ± {accuracy_std:.4f}")
print(f"Precision.........{precision_mean:.4f} ± {precision_std:.4f}")
print(f"Significance......{significance_mean:.4f} ± {significance_std:.4f}")
# Out:
# True positives....24382.00 ± 94.14
# False positives...2833.10 ± 15.85
# Accuracy..........0.6966 ± 0.0011
# Precision.........0.8959 ± 0.0003
# Significance......458.0780 ± 0.9130

# %%
# Analysis: learned cuts (x10)
cut_boundaries = []
cut_expressions = []
cut_cases = []
cut_indices = []

for i in range(x_test.shape[1]):
    case = checkpoints[0].cuts[i].case
    index = checkpoints[0].cuts[i].index
    boundaries = []

    for checkpoint in checkpoints:
        assert checkpoint.cuts[i].case == case
        assert checkpoint.cuts[i].index == index
        boundaries.append(checkpoint.cuts[i].boundaries)

    boundaries_mean = ops.mean(boundaries, axis=0)
    boundaries_std = ops.std(boundaries, axis=0)

    feature = checkpoints[0].cuts[i].feature
    if case == 1:
        print(f"{feature} < {boundaries_mean[index]:.4f} ± {boundaries_std[index]:.4f}")
        expression = f"{feature} < {boundaries_mean[index]:.4f}"
    elif case == 2:
        print(f"{feature} > {boundaries_mean[index]:.4f} ± {boundaries_std[index]:.4f}")
        expression = f"{feature} > {boundaries_mean[index]:.4f}"
    elif case == 3:
        print(
            f"{boundaries_mean[0]:.4f} ± {boundaries_std[0]:.4f} < {feature} "
            f"< {boundaries_mean[1]:.4f} ± {boundaries_std[1]:.4f}"
        )
        expression = f"{boundaries_mean[0]:.4f} < {feature} < {boundaries_mean[1]:.4f}"
    else:
        print(
            f"{feature} < {boundaries_mean[0]:.4f} ± {boundaries_std[0]:.4f} or "
            f"{feature} > {boundaries_mean[1]:.4f} ± {boundaries_std[1]:.4f}"
        )
        expression = (
            f"{feature} < {boundaries_mean[0]:.4f} or "
            f"{feature} > {boundaries_mean[1]:.4f}"
        )
    cut_boundaries.append(boundaries_mean)
    cut_expressions.append(expression)
    cut_cases.append(case)
    cut_indices.append(index)
# Out:
# 56.1322 ± 0.0352 < $M_{jet}$ < 110.9025 ± 0.2137
# 0.0667 ± 0.0003 < $C_2^{\beta=1}$ < 0.2137 ± 0.0006
# 0.0056 ± 0.0010 < $C_2^{\beta=2}$ < 0.1248 ± 0.0017
# $D_2^{\beta=1}$ < 1.5396 ± 0.0010
# $D_2^{\beta=2}$ < 1.3538 ± 0.0014
# $\tau_{21}^{\beta=1}$ < 0.4264 ± 0.0009

# %%
# Figure: learned cuts
features_str = [tex_to_str(feature) for feature in features]

df = pd.DataFrame(x_test, columns=features_str)
df["y"] = y_test.squeeze()

for i, feature in enumerate(features):
    sig = df.query("y == 1")[features_str[i]]
    bkg = df.query("y == 0")[features_str[i]]
    weights_sig = 100 * np.ones_like(sig) / len(df)
    weights_bkg = 100 * np.ones_like(bkg) / len(df)

    plot_learned_cut(
        case=cut_cases[i],
        index=cut_indices[i],
        boundaries=cut_boundaries[i],
        expression=cut_expressions[i],
        data=[sig, bkg],
        bins=bins,
        colors=["red", "blue"],
        labels=["SIG.", "BKG."],
        weights=[weights_sig, weights_bkg],
        xlabel=feature,
        ylabel="Percentage",
    )
    plot_learned_cut(
        case=cut_cases[i],
        index=cut_indices[i],
        boundaries=cut_boundaries[i],
        expression=cut_expressions[i],
        data=[sig, bkg],
        bins=bins,
        colors=["red", "blue"],
        labels=["SIG.", "BKG."],
        weights=[weights_sig, weights_bkg],
        xlabel=feature,
        ylabel="Percentage",
        to_file=FIGURES_DIR / f"learned_cut-{tex_to_str(feature)}(x10).pdf",
    )

    if isinstance(checkpoint, LearnableCutFlowSequentialModel):
        cut_query = checkpoint.cuts[i].expression.replace(
            features[i], f"`{features_str[i]}`"
        )
        df = df.query(cut_query)

# %%
# Analysis: learned importance (x10)
importance_score_means = []
importance_score_stds = []

for i in range(x_test.shape[1]):
    for checkpoint in checkpoints:
        assert checkpoint.cuts[i].case == checkpoints[0].cuts[i].case
        assert checkpoint.cuts[i].index == checkpoints[0].cuts[i].index

importance_scores = []
for checkpoint in checkpoints:
    importance_scores.append(checkpoint.importance.scores)

importance_scores_mean = ops.mean(importance_scores, axis=0)
importance_scores_std = ops.std(importance_scores, axis=0)

for i in range(x_test.shape[1]):
    print(f"{importance_scores_mean[i]:.4f} ± {importance_scores_std[i]:.4f}")
# Out:
# 0.3428 ± 0.0073
# 0.1186 ± 0.0073
# 0.0620 ± 0.0050
# 0.1837 ± 0.0106
# 0.2177 ± 0.0085
# 0.0751 ± 0.0038

# %%
# Figure: learned importance (x10)
plot_learned_importance(
    scores=importance_scores_mean,
    errors=importance_scores_std,
    baseline=checkpoint.importance.baseline,
    features=features,
)
plot_learned_importance(
    scores=importance_scores_mean,
    errors=importance_scores_std,
    baseline=checkpoint.importance.baseline,
    features=features,
    to_file=FIGURES_DIR / "learned_importance(x10).pdf",
)
