# %%
# Configuration
import os
import sys

os.environ["KERAS_BACKEND"] = "jax"
sys.path.append("..")

# %%
# Setup
from importlib import import_module
from typing import cast

import numpy as np
from keras import ops
from keras.models import Model, load_model

from src.utils import (
    show_learned_cut,
    show_learned_cuts,
    show_learned_importance,
    show_record_dataset,
    show_record_dataset_correlation,
)

# %%
# Parameters

# Dataset
dataset_name = "mock4"
n_samples = 200000
seed = 42

# Model
model_builder_name = "LearnableCutFlowParallel"
centers = [-2, -1.8, -1.4]
n_epochs = 200
batch_size = 512

# Figure
bins = np.linspace(-10, 10, 101)
feature_names = ["x1", "x9", "x10"]
feature_names_latex = ["$x_1$", "$x_9$", "$x_{10}$"]

# %%
# Dataset
load_data = import_module(f"src.datasets.{dataset_name}").load_data
(x_train, y_train), (x_test, y_test) = load_data(n_samples, seed)

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")

# Figure: feature distribution
show_record_dataset(x_train, y_train, bins, feature_names_latex)

# Figure: feature correlation
show_record_dataset_correlation(x_train, feature_names_latex)
# Out:
# x_train.shape=(100000, 3)
# y_train.shape=(100000, 1)
# x_test.shape=(100000, 3)
# y_test.shape=(100000, 1)

# %%
# Model
ModelBuilder = getattr(import_module("src.models"), model_builder_name)
model = ModelBuilder(x_train.shape, centers, name="lcf_par")
model.normalization.adapt(x_train)
model.compile(optimizer="adam", loss="crossentropy")
model.fit(x_train, y_train, epochs=n_epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.4065
# Epoch 2/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3672
# Epoch 3/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3366
# Epoch 4/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3129
# Epoch 5/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2959
# Epoch 6/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2836
# Epoch 7/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2740
# Epoch 8/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2673
# Epoch 9/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2605
# Epoch 10/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2559
# Epoch 11/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2504
# Epoch 12/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2478
# Epoch 13/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2425
# Epoch 14/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2389
# Epoch 15/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2362
# Epoch 16/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2332
# Epoch 17/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2301
# Epoch 18/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2289
# Epoch 19/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2256
# Epoch 20/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2242
# Epoch 21/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2207
# Epoch 22/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2198
# Epoch 23/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2178
# Epoch 24/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2158
# Epoch 25/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2144
# Epoch 26/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2139
# Epoch 27/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2123
# Epoch 28/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2119
# Epoch 29/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2109
# Epoch 30/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2088
# Epoch 31/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2097
# Epoch 32/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2089
# Epoch 33/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2075
# Epoch 34/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2070
# Epoch 35/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2059
# Epoch 36/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2058
# Epoch 37/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2056
# Epoch 38/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2056
# Epoch 39/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2047
# Epoch 40/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2044
# Epoch 41/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2036
# Epoch 42/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.2047
# Epoch 43/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2036
# Epoch 44/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2039
# Epoch 45/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 46/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2036
# Epoch 47/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034
# Epoch 48/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2041
# Epoch 49/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019
# Epoch 50/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2008
# Epoch 51/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2033
# Epoch 52/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2024
# Epoch 53/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2022
# Epoch 54/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026
# Epoch 55/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034
# Epoch 56/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012
# Epoch 57/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2026
# Epoch 58/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2023
# Epoch 59/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2014
# Epoch 60/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2028
# Epoch 61/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2033
# Epoch 62/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 63/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2005
# Epoch 64/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.2025
# Epoch 65/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 66/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 67/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 68/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010
# Epoch 69/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2023
# Epoch 70/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.2026
# Epoch 71/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 72/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2031
# Epoch 73/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.2032
# Epoch 74/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2009
# Epoch 75/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 76/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 77/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 78/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026
# Epoch 79/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 80/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2028
# Epoch 81/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 82/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 83/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010
# Epoch 84/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.2016
# Epoch 85/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.2017
# Epoch 86/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.2027
# Epoch 87/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2008
# Epoch 88/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.1994
# Epoch 89/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - loss: 0.2014
# Epoch 90/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2006
# Epoch 91/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.2015
# Epoch 92/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2009
# Epoch 93/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026
# Epoch 94/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2023
# Epoch 95/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012
# Epoch 96/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2011
# Epoch 97/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2020
# Epoch 98/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1998
# Epoch 99/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.2015
# Epoch 100/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2014
# Epoch 101/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.2019
# Epoch 102/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 103/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.2024
# Epoch 104/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019
# Epoch 105/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2033
# Epoch 106/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2022
# Epoch 107/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 108/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2016
# Epoch 109/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2011
# Epoch 110/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.2016
# Epoch 111/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.2022
# Epoch 112/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 113/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 114/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 115/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2006
# Epoch 116/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034
# Epoch 117/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012
# Epoch 118/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2019
# Epoch 119/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013
# Epoch 120/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012
# Epoch 121/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.2014
# Epoch 122/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.2016
# Epoch 123/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2016
# Epoch 124/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 125/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007
# Epoch 126/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.2013
# Epoch 127/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 128/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 129/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 130/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2009
# Epoch 131/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034
# Epoch 132/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 133/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019
# Epoch 134/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2009
# Epoch 135/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 136/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.2010
# Epoch 137/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2016
# Epoch 138/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 0.2000
# Epoch 139/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007
# Epoch 140/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.2013
# Epoch 141/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.2012
# Epoch 142/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2014
# Epoch 143/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013
# Epoch 144/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2016
# Epoch 145/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.2020
# Epoch 146/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2024
# Epoch 147/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2008
# Epoch 148/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 149/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 150/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007
# Epoch 151/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013
# Epoch 152/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 153/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 0.2004
# Epoch 154/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2004
# Epoch 155/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010
# Epoch 156/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.2017
# Epoch 157/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2023
# Epoch 158/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 159/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010
# Epoch 160/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1996
# Epoch 161/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2003
# Epoch 162/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2008
# Epoch 163/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2005
# Epoch 164/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2029
# Epoch 165/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 166/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.2014
# Epoch 167/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.2014
# Epoch 168/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018
# Epoch 169/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 170/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2010
# Epoch 171/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2024
# Epoch 172/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2026
# Epoch 173/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2002
# Epoch 174/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2014
# Epoch 175/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 176/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019
# Epoch 177/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2006
# Epoch 178/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012
# Epoch 179/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 180/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021
# Epoch 181/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2015
# Epoch 182/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2014
# Epoch 183/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012
# Epoch 184/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 185/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 186/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015
# Epoch 187/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019
# Epoch 188/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.2012
# Epoch 189/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025
# Epoch 190/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2020
# Epoch 191/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2020
# Epoch 192/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021
# Epoch 193/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034
# Epoch 194/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 195/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017
# Epoch 196/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2018
# Epoch 197/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013
# Epoch 198/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2011
# Epoch 199/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2003
# Epoch 200/200
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026

# %%
# Save model
checkpoint_name = f"exp-{dataset_name}-{model.name}"
model.save(f"checkpoints/{checkpoint_name}.keras")
checkpoint = cast(Model, load_model(f"checkpoints/{checkpoint_name}.keras"))

# %%
# Analysis: metrics
y_pred = checkpoint.predict(x_test, batch_size=batch_size)
y_true = y_test

tp = ops.sum((y_true == 1) & (y_pred == 1))
fp = ops.sum((y_true == 0) & (y_pred == 1))
tn = ops.sum((y_true == 0) & (y_pred == 0))
fn = ops.sum((y_true == 1) & (y_pred == 0))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# True positives.......35032
# False positives.......4720
# Accuracy............0.8045
# Precision...........0.8813
# Significance......509.9105

# %%
# Analysis: check metrics via learned cuts
mask = ops.ones_like(x_test[:, 0], dtype="bool")
n_features = x_test.shape[1]
selection = (
    checkpoint.learned_importance > 1 / n_features * checkpoint.importance_min_percent
)
for i, cut_report in enumerate(checkpoint.learned_cuts_report):
    if not selection[i]:
        continue

    x_i = x_test[:, i]
    boundaries = cut_report["boundaries"]
    index = cut_report["index"]

    if cut_report["case"] == "left":
        mask_i = x_i < boundaries[index]
    elif cut_report["case"] == "right":
        mask_i = x_i > boundaries[index]
    elif cut_report["case"] == "middle":
        mask_i = ops.logical_and(boundaries[0] < x_i, x_i < boundaries[1])
    else:
        mask_i = ops.logical_or(x_i < boundaries[0], boundaries[1] < x_i)
    mask = ops.logical_and(mask, mask_i)

y_pred_cut = ops.cast(mask, dtype="float32")
y_pred_cut = ops.reshape(y_pred_cut, y_test.shape)
tp = ops.sum((y_pred_cut == 1) & (y_test == 1))
fp = ops.sum((y_pred_cut == 1) & (y_test == 0))
tn = ops.sum((y_pred_cut == 0) & (y_test == 0))
fn = ops.sum((y_pred_cut == 0) & (y_test == 1))

n_preds_true = ops.add(tp, tn)
n_preds_false = ops.add(fp, fn)
n_positives = ops.add(tp, fp)
n_samples = ops.add(n_preds_true, n_preds_false)

accuracy = ops.divide(n_preds_true, n_samples)
precision = ops.divide(tp, n_positives)
significance = ops.divide(tp, ops.sqrt(fp))

print(f"True positives..{tp:.>10}")
print(f"False positives.{fp:.>10}")
print(f"Accuracy........{accuracy:.>10.4f}")
print(f"Precision.......{precision:.>10.4f}")
print(f"Significance....{significance:.>10.4f}")
# Out:
# True positives.......35032
# False positives.......4720
# Accuracy............0.8045
# Precision...........0.8813
# Significance......509.9105

# %%
# Analysis: learned cuts
for learned_cut in checkpoint.learned_cuts:
    print(learned_cut)
# Out:
# x1 < 0.0174
# x2 < 0.0098
# x3 < 0.0114

# %%
# Figure: learned cuts
show_learned_cuts(checkpoint, x_test, y_test, bins, feature_names_latex)

# Save in png and pdf
for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_cut_{i + 1}.png",
    )
for i in range(len(checkpoint.learned_cuts)):
    show_learned_cut(
        i,
        checkpoint,
        x_test,
        y_test,
        bins,
        feature_names_latex[i],
        to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_cut_{i + 1}.pdf",
    )

# %%
# Figure: learned importance
show_learned_importance(checkpoint, feature_names_latex)

# Save in png and pdf
show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_importance.png",
)
show_learned_importance(
    checkpoint,
    feature_names_latex,
    to_file=f"figures/exp-{dataset_name}-{checkpoint.name}-learned_importance.pdf",
)
